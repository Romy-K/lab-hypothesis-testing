# %% [markdown]
# # Lab | Hypothesis Testing

# %% [markdown]
# **Objective**
#
# Welcome to the Hypothesis Testing Lab, where we embark on an enlightening journey through the realm of statistical decision-making! In this laboratory, we delve into various scenarios, applying the powerful tools of hypothesis testing to scrutinize and interpret data.
#
# From testing the mean of a single sample (One Sample T-Test), to investigating differences between independent groups (Two Sample T-Test), and exploring relationships within dependent samples (Paired Sample T-Test), our exploration knows no bounds. Furthermore, we'll venture into the realm of Analysis of Variance (ANOVA), unraveling the complexities of comparing means across multiple groups.
#
# So, grab your statistical tools, prepare your hypotheses, and let's embark on this fascinating journey of exploration and discovery in the world of hypothesis testing!

# %% [markdown]
# **Challenge 1**

# %% [markdown]
# In this challenge, we will be working with pokemon data. The data can be found here:
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/pokemon.csv

# %%
#libraries
import pandas as pd
import scipy.stats as st
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from scipy.stats import ttest_ind

# %%
df = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/pokemon.csv")
df
# Out:
#                Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0         Bulbasaur    Grass  Poison  45      49       49       65       65
# 1           Ivysaur    Grass  Poison  60      62       63       80       80
# 2          Venusaur    Grass  Poison  80      82       83      100      100
# 3     Mega Venusaur    Grass  Poison  80     100      123      122      120
# 4        Charmander     Fire     NaN  39      52       43       60       50
# ..              ...      ...     ...  ..     ...      ...      ...      ...
# 795         Diancie     Rock   Fairy  50     100      150      100      150
# 796    Mega Diancie     Rock   Fairy  50     160      110      160      110
# 797  Hoopa Confined  Psychic   Ghost  80     110       60      150      130
# 798   Hoopa Unbound  Psychic    Dark  80     160       60      170      130
# 799       Volcanion     Fire   Water  80     110      120      130       90
#
#      Speed  Generation  Legendary
# ...

# %% [markdown]
# - We posit that Pokemons of type Dragon have, on average, more HP stats than Grass. Choose the propper test and, with 5% significance, comment your findings.

# %%
#code here
# First, create new dfs for Grass and Dragon 
grass_df = df[(df['Type 1'] == 'Grass') | (df['Type 2'] == 'Grass')]

# Dragon-type Pokémon (either in Type 1 or Type 2)
dragon_df = df[(df['Type 1'] == 'Dragon') | (df['Type 2'] == 'Dragon')]

# %%
grass_df.describe()
# Out:
#                HP      Attack     Defense     Sp. Atk     Sp. Def       Speed  \
# count   95.000000   95.000000   95.000000   95.000000   95.000000   95.000000
# mean    66.052632   73.463158   73.252632   72.936842   71.505263   60.715789
# std     18.861967   24.168210   24.891239   26.270609   20.694266   27.387551
# min     30.000000   27.000000   30.000000   24.000000   30.000000   10.000000
# 25%     50.000000   57.000000   55.000000   54.500000   55.000000   40.000000
# 50%     65.000000   70.000000   70.000000   65.000000   70.000000   56.000000
# 75%     75.000000   94.500000   85.000000   90.000000   85.000000   80.000000
# max    123.000000  132.000000  131.000000  145.000000  129.000000  145.000000
#
#        Generation
# count   95.000000
# mean     3.652632
# std      1.668025
# min      1.000000
# 25%      2.000000
# 50%      4.000000
# 75%      5.000000
# max      6.000000

# %%
dragon_df.describe()
# Out:
#               HP      Attack     Defense     Sp. Atk     Sp. Def       Speed  \
# count   50.00000   50.000000   50.000000   50.000000   50.000000   50.000000
# mean    82.90000  105.760000   86.620000   97.440000   86.900000   82.140000
# std     25.65171   31.928849   24.163465   41.088834   28.606586   25.286126
# min     40.00000   30.000000   35.000000   30.000000   30.000000   38.000000
# 25%     66.50000   84.250000   70.000000   60.000000   70.000000   58.500000
# 50%     80.00000  100.000000   90.000000   98.500000   90.000000   90.000000
# 75%     98.75000  127.750000  100.000000  128.750000  103.750000   99.500000
# max    150.00000  180.000000  130.000000  180.000000  150.000000  145.000000
#
#        Generation
# count   50.000000
# mean     3.980000
# std      1.477588
# min      1.000000
# 25%      3.000000
# 50%      4.000000
# 75%      5.000000
# max      6.000000

# %%
# Histogram for Grass HP 

sns.histplot(grass_df['HP'], kde=True, color="salmon")
plt.show()

# %%
# Histogram for Dragon HP

sns.histplot(dragon_df['HP'], kde=True, color="blue")
plt.show()

# %%
# Check distribution of both dfs, use Shapiro for smaller sample size

# H0 = Distribution is normal 
# H1 = Distribution is not normal

# Conducting the Shapiro-Wilk test for normality on Dragon HP
shapiro_stat_grass, shapiro_p_grass = stats.shapiro(grass_df['HP'])

shapiro_stat_grass, shapiro_p_grass 
# Distribution is close to normal, but not normal
# Out:
# (0.9721423944405221, 0.04023071193635895)

# %%
# Conducting the Shapiro-Wilk test for normality on Dragon HP
shapiro_stat_dragon, shapiro_p_dragon = stats.shapiro(dragon_df['HP'])

shapiro_stat_dragon, shapiro_p_dragon
# Distribution is normal
# Out:
# (0.9629854486046097, 0.11856755643275282)

# %%
# Q-Q for extra visual aid - Grass

stats.probplot(grass_df['HP'], plot=plt)
plt.show()

# %%
# Q-Q for extra visual aid - Dragon

stats.probplot(dragon_df['HP'], plot=plt)
plt.show()

# %%
# I think they are normal enough to try t-testing. 
# First, check if variances are equal 

from scipy.stats import levene
stat, p = levene(dragon_df['HP'], grass_df['HP'])
print(f"Levene's test p-value: {p:.5f}")
# Out:
# Levene's test p-value: 0.06699

# %%
# Independent two-sample t-test with equal variance
t_stat, t_p = stats.ttest_ind(dragon_df['HP'], grass_df['HP'], equal_var=True)

print(f"T-test Statistic: {t_stat:.4f}")
print(f"P-value: {t_p:.5f}")

# H0 = There is no relation between dragon HP and grass HP 
# p = < 0,05, so we reject the hypothesis. There is a significant relationship between dragon HP and grass HP.
# Out:
# T-test Statistic: 4.4991
# P-value: 0.00001

# %% [markdown]
# - We posit that Legendary Pokemons have different stats (HP, Attack, Defense, Sp.Atk, Sp.Def, Speed) when comparing with Non-Legendary. Choose the propper test and, with 5% significance, comment your findings.

# %%
# Hypothesis: there is a significant difference between legendary and non-legendary pokemon when it comes to their stats.

# %%
# Legendary column is a boolean.
print(df.Legendary.value_counts())
# Let's create separate groups first

legendary = df[df['Legendary'] == True]
non_legendary = df[df['Legendary'] == False]
# Out:
# Legendary
# False    735
# True      65
# Name: count, dtype: int64

# %%
# Now, t-test all of the stat groups separately 

for stat in ['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']:
    t_stat, p_val = ttest_ind(legendary[stat], non_legendary[stat], equal_var=False)
    print(f"{stat}: t={t_stat:.4f}, p={p_val:.5f}")

# We can reject the null hypothesis: there is a statistically significant different between the stats of legendary and non-legendary pokemon.
# Out:
# HP: t=8.9814, p=0.00000
# Attack: t=10.4381, p=0.00000
# Defense: t=7.6371, p=0.00000
# Sp. Atk: t=13.4174, p=0.00000
# Sp. Def: t=10.0157, p=0.00000
# Speed: t=11.4750, p=0.00000

# %%
# I want to check them all in a bunch as well. We use MANOVA (and clean up the column names) 
from statsmodels.multivariate.manova import MANOVA

manova = MANOVA.from_formula('HP + Attack + Defense + Sp_Atk + Sp_Def + Speed ~ Legendary', data=df.rename(columns={'Sp. Atk': 'Sp_Atk', 'Sp. Def': 'Sp_Def'}))
print(manova.mv_test())

# Hypothesis confirmed: P values are 0, there is a statistically significant difference between Legendary and non-Legendary stats
# Out:
#                    Multivariate linear model
# ...
#
# ----------------------------------------------------------------
#        Intercept         Value  Num DF  Den DF   F Value  Pr > F
# ----------------------------------------------------------------
#           Wilks' lambda  0.0592 6.0000 793.0000 2100.8338 0.0000
#          Pillai's trace  0.9408 6.0000 793.0000 2100.8338 0.0000
#  Hotelling-Lawley trace 15.8953 6.0000 793.0000 2100.8338 0.0000
#     Roy's greatest root 15.8953 6.0000 793.0000 2100.8338 0.0000
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
#           Legendary        Value  Num DF  Den DF  F Value Pr > F
# ----------------------------------------------------------------
#              Wilks' lambda 0.7331 6.0000 793.0000 48.1098 0.0000
#             Pillai's trace 0.2669 6.0000 793.0000 48.1098 0.0000
#     Hotelling-Lawley trace 0.3640 6.0000 793.0000 48.1098 0.0000
# ...

# %% [markdown]
# **Challenge 2**

# %% [markdown]
# In this challenge, we will be working with california-housing data. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/california_housing.csv

# %%
df = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/california_housing.csv")
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %% [markdown]
# **We posit that houses close to either a school or a hospital are more expensive.**
#
# - School coordinates (-118, 34)
# - Hospital coordinates (-122, 37)
#
# We consider a house (neighborhood) to be close to a school or hospital if the distance is lower than 0.50.
#
# Hint:
# - Write a function to calculate euclidean distance from each house (neighborhood) to the school and to the hospital.
# - Divide your dataset into houses close and far from either a hospital or school.
# - Choose the propper test and, with 5% significance, comment your findings.

# %%
school_coord = (-118, 34)
hospital_coord = (-122, 37)

# Function to calculate Euclidean distance
def euclidean_dist(lon1, lat1, lon2, lat2):
    return np.sqrt((lon2 - lon1)**2 + (lat2 - lat1)**2)

# Add new columns for distances
df['distance_to_school'] = df.apply(lambda row: euclidean_dist(row['longitude'], row['latitude'], *school_coord), axis=1)
df['distance_to_hospital'] = df.apply(lambda row: euclidean_dist(row['longitude'], row['latitude'], *hospital_coord), axis=1)

df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
df_close_houses = df[(df['distance_to_school'] < 0.50) | (df['distance_to_hospital'] < 0.50)]
df_far_houses = df[(df['distance_to_school'] >= 0.50) & (df['distance_to_hospital'] >= 0.50)]

# %%
df_close_houses
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2366     -117.51     34.00                36.0       3791.0           746.0
# 2367     -117.51     33.97                35.0        352.0            62.0
# 2368     -117.51     33.95                12.0       9016.0          1486.0
# 2371     -117.52     33.99                14.0      13562.0          2057.0
# 2372     -117.52     33.89                 2.0      17978.0          3217.0
# ...          ...       ...                 ...          ...             ...
# 15090    -122.25     37.08                20.0       1201.0           282.0
# 15170    -122.26     37.38                28.0       1103.0           164.0
# 15253    -122.27     37.32                37.0       2607.0           534.0
# 15254    -122.27     37.24                30.0       2762.0           593.0
# 15686    -122.38     37.18                52.0       1746.0           315.0
#
# ...

# %%
df_far_houses
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
# Check if distribution is normal for both 

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

sns.histplot(df_close_houses['median_house_value'], kde=True, color='blue', label='Close', stat='density')
sns.histplot(df_far_houses['median_house_value'], kde=True, color='red', label='Far', stat='density')

plt.title("Distribution of Median House Values")
plt.xlabel("Median House Value")
plt.ylabel("Density")
plt.legend()
plt.show()

# %%
# Distribution is not normal for both groups
# Use Mann-Whitney U test

# %%
from scipy.stats import mannwhitneyu

stat, p = mannwhitneyu(df_close_houses['median_house_value'], df_far_houses['median_house_value'], alternative='two-sided')
print(f"U-statistic = {stat:.2f}, p-value = {p:.5f}")
# Out:
# U-statistic = 48257337.50, p-value = 0.00000

# %%
# We can reject the null: there is a significant difference between the two groups. Our hypothesis is supported.
